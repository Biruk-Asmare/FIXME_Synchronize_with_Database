# %%
library(ggplot2)

# %%
projs= read.csv("combined_projects_commit_time_stat.csv")
summary(projs)
# Out:
#                       Subject.system   Snapshots           Mean
#  adempiere_adempiere         : 1     Min.   :  2.00   Min.   :  25.13
#  AdrienPoupa_VinylMusicPlayer: 1     1st Qu.:  3.00   1st Qu.: 197.08
#  AndlyticsProject_andlytics  : 1     Median :  6.50   Median : 325.19
#  ankidroid_Anki-Android      : 1     Mean   : 12.30   Mean   : 444.03
#  AntennaPod_AntennaPod       : 1     3rd Qu.: 13.75   3rd Qu.: 587.42
#  apiman_apiman               : 1     Max.   :107.00   Max.   :2542.50
#  (Other)                     :96
#        SD            X95_CI_low       X95_CI_high        group
#  Min.   :  12.10   Min.   :-1674.4   Min.   :  30.05   NoSQL:19
#  1st Qu.:  98.25   1st Qu.:   50.7   1st Qu.: 277.49   SQL  :83
#  Median : 213.96   Median :  140.6   Median : 495.25
#  Mean   : 317.30   Mean   :  127.1   Mean   : 760.92
#  3rd Qu.: 383.68   3rd Qu.:  222.8   3rd Qu.: 940.86
#  Max.   :3058.24   Max.   :  843.8   Max.   :6759.37

# %%
ggplot(projs, aes(fill=group,x=as.factor(group),y=Mean))+
geom_boxplot(position = "dodge", notch="true") +
scale_y_continuous(trans='log2')+
geom_point()+
xlab("") + 
ylab (expression(paste("Average number of days"))) +
scale_fill_discrete(name = "Subject systems")+
theme(legend.position = "none")
#ggsave("RQ1_projs_boxplot.pdf",width=6, height = 4, units = "in")
# Out:
# notch went outside hinges. Try setting notch=FALSE.
# plot without title
