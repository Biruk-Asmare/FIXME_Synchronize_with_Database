# %%
library(ggplot2)

# %% [markdown]
# <h2>Distribution of commits in subject systems</h2>

# %%
projs= read.csv("projects.csv")
summary(projs)
# Out:
#                          project       latest        totalCommits     group
#  adempiere_adempiere         : 1   Min.   :  3.00   Min.   : 1001   NoSQL:19
#  AdrienPoupa_VinylMusicPlayer: 1   1st Qu.:  4.00   1st Qu.: 1501   SQL  :83
#  AndlyticsProject_andlytics  : 1   Median :  7.50   Median : 3251
#  ankidroid_Anki-Android      : 1   Mean   : 13.30   Mean   : 6153
#  AntennaPod_AntennaPod       : 1   3rd Qu.: 14.75   3rd Qu.: 6876
#  apiman_apiman               : 1   Max.   :108.00   Max.   :53501
#  (Other)                     :96

# %%
ggplot(projs, aes(fill=group,x=as.factor(group),y=totalCommits))+
geom_boxplot(position = "dodge", notch="true") +
scale_y_continuous(trans='log2')+
geom_point()+
xlab("") + 
ylab (expression(paste("Number of commits"))) +
scale_fill_discrete(name = "Subject systems")+
theme(legend.position = "none")
ggsave("RQ1_projs_boxplot.pdf",width=6, height = 4, units = "in")
# Out:
# plot without title

# %% [markdown]
# <h2>Plots on G1</h2>

# %%
#read the data
sql_g1= read.csv("sql_G1.csv")
nosql_g1=read.csv("nosql_G1.csv")
sql_g1$group="SQL"
nosql_g1$group <-"NoSQL"

# %%
#sql_g1$version <- (sql_g1$version*500)-(500+1)
#nosql_g1$version<- (nosql_g1$version*500)-(500+1)
g1 <- rbind(sql_g1,nosql_g1)
summary(sql_g1)
summary(nosql_g1)
summary(g1)
head(g1)
tail(g1)
# Out:
#     version                               project     dac_count
#  Min.   :1.000   AdrienPoupa_VinylMusicPlayer : 4   Min.   :  0.00
#  1st Qu.:1.000   AndlyticsProject_andlytics   : 4   1st Qu.:  0.75
#  Median :2.000   AppLozic_Applozic-Android-SDK: 4   Median :  2.00
#  Mean   :2.361   bbossgroups_bboss            : 4   Mean   : 24.74
#  3rd Qu.:3.000   bither_bither-android        : 4   3rd Qu.: 14.25
#  Max.   :4.000   Blazebit_blaze-persistence   : 4   Max.   :380.00
#                  (Other)                      :48
#  non_dac_count    analysis_group     commit          group
#  Min.   :  1.00   G1:72          Min.   :   1.0   Length:72
#  1st Qu.: 12.00                  1st Qu.:   1.0   Class :character
#  Median : 23.50                  Median : 501.0   Mode  :character
#  Mean   : 56.19                  Mean   : 681.6
#  3rd Qu.: 64.00                  3rd Qu.:1001.0
#  Max.   :412.00                  Max.   :1501.0
#     version                        project     dac_count      non_dac_count
#  Min.   :1.000   bbossgroups_bboss     : 4   Min.   :  0.00   Min.   :  0.00
#  1st Qu.:1.000   IHTSDO_snowstorm      : 4   1st Qu.:  0.00   1st Qu.:  7.00
#  Median :2.000   OpenSextant_Xponents  : 4   Median :  2.00   Median : 26.00
#  Mean   :2.326   pietermartin_sqlg     : 4   Mean   : 11.56   Mean   : 72.07
#  3rd Qu.:3.000   qalingo_qalingo-engine: 4   3rd Qu.: 15.00   3rd Qu.: 84.00
#  Max.   :4.000   romanchyla_montysolr  : 4   Max.   :129.00   Max.   :477.00
#                  (Other)               :19
#  analysis_group     commit          group
#  G1:43          Min.   :   1.0   Length:43
#                 1st Qu.:   1.0   Class :character
#                 Median : 501.0   Mode  :character
#                 Mean   : 663.8
#                 3rd Qu.:1001.0
#                 Max.   :1501.0
#     version                               project     dac_count
#  Min.   :1.000   bbossgroups_bboss            : 8   Min.   :  0.00
#  1st Qu.:1.000   AdrienPoupa_VinylMusicPlayer : 4   1st Qu.:  0.00
#  Median :2.000   AndlyticsProject_andlytics   : 4   Median :  2.00
#  Mean   :2.348   AppLozic_Applozic-Android-SDK: 4   Mean   : 19.81
#  3rd Qu.:3.000   bither_bither-android        : 4   3rd Qu.: 14.50
#  Max.   :4.000   Blazebit_blaze-persistence   : 4   Max.   :380.00
#                  (Other)                      :87
#  non_dac_count    analysis_group     commit          group
#  Min.   :  0.00   G1:115         Min.   :   1.0   Length:115
#  1st Qu.: 10.50                  1st Qu.:   1.0   Class :character
#  Median : 25.00                  Median : 501.0   Mode  :character
#  Mean   : 62.13                  Mean   : 674.9
#  3rd Qu.: 69.50                  3rd Qu.:1001.0
#  Max.   :477.00                  Max.   :1501.0
#   version project           dac_count non_dac_count analysis_group commit group
# 1 1       virgo47_javasimon  0          4           G1                1   SQL
# 2 2       virgo47_javasimon  1         10           G1              501   SQL
# 3 3       virgo47_javasimon  2         13           G1             1001   SQL
# 4 1       bbossgroups_bboss 23        281           G1                1   SQL
# 5 2       bbossgroups_bboss 65        412           G1              501   SQL
# 6 3       bbossgroups_bboss 79        293           G1             1001   SQL
#     version project                                   dac_count non_dac_count
# 110 2       spring-projects_spring-data-elasticsearch 1         0
# 111 3       spring-projects_spring-data-elasticsearch 3         2
# 112 1       RyanSusana_elepy                          0         1
# 113 2       RyanSusana_elepy                          0         2
# 114 3       RyanSusana_elepy                          0         2
# 115 4       RyanSusana_elepy                          1         8
#     analysis_group commit group
# 110 G1              501   NoSQL
# 111 G1             1001   NoSQL
# 112 G1                1   NoSQL
# 113 G1              501   NoSQL
# 114 G1             1001   NoSQL
# 115 G1             1501   NoSQL

# %%
head(sql_g1)
# Out:
#   version project           dac_count non_dac_count analysis_group commit group
# 1 1       virgo47_javasimon  0          4           G1                1   SQL
# 2 2       virgo47_javasimon  1         10           G1              501   SQL
# 3 3       virgo47_javasimon  2         13           G1             1001   SQL
# 4 1       bbossgroups_bboss 23        281           G1                1   SQL
# 5 2       bbossgroups_bboss 65        412           G1              501   SQL
# 6 3       bbossgroups_bboss 79        293           G1             1001   SQL

# %%
#This code was taken from the stackoverflow ansower by jan-glx's (https://stackoverflow.com/a/45614547)
GeomSplitViolin <- ggproto("GeomSplitViolin", GeomViolin, 
                           draw_group = function(self, data, ..., draw_quantiles = NULL) {
  data <- transform(data, xminv = x - violinwidth * (x - xmin), xmaxv = x + violinwidth * (xmax - x))
  grp <- data[1, "group"]
  newdata <- plyr::arrange(transform(data, x = if (grp %% 2 == 1) xminv else xmaxv), if (grp %% 2 == 1) y else -y)
  newdata <- rbind(newdata[1, ], newdata, newdata[nrow(newdata), ], newdata[1, ])
  newdata[c(1, nrow(newdata) - 1, nrow(newdata)), "x"] <- round(newdata[1, "x"])

  if (length(draw_quantiles) > 0 & !scales::zero_range(range(data$y))) {
    stopifnot(all(draw_quantiles >= 0), all(draw_quantiles <=
      1))
    quantiles <- ggplot2:::create_quantile_segment_frame(data, draw_quantiles)
    aesthetics <- data[rep(1, nrow(quantiles)), setdiff(names(data), c("x", "y")), drop = FALSE]
    aesthetics$alpha <- rep(1, nrow(quantiles))
    both <- cbind(quantiles, aesthetics)
    quantile_grob <- GeomPath$draw_panel(both, ...)
    ggplot2:::ggname("geom_split_violin", grid::grobTree(GeomPolygon$draw_panel(newdata, ...), quantile_grob))
  }
  else {
    ggplot2:::ggname("geom_split_violin", GeomPolygon$draw_panel(newdata, ...))
  }
})

geom_split_violin <- function(mapping = NULL, data = NULL, stat = "ydensity", position = "identity", ..., 
                              draw_quantiles = NULL, trim = TRUE, scale = "area", na.rm = FALSE, 
                              show.legend = NA, inherit.aes = TRUE) {
  layer(data = data, mapping = mapping, stat = stat, geom = GeomSplitViolin, 
        position = position, show.legend = show.legend, inherit.aes = inherit.aes, 
        params = list(trim = trim, scale = scale, draw_quantiles = draw_quantiles, na.rm = na.rm, ...))
}

# %%
ggplot(g1, aes(fill=group,x=as.factor(commit), y=non_dac_count))+
scale_y_continuous(trans='log2')+
geom_split_violin(position = "dodge",draw_quantiles=c(0.25, 0.5, 0.75)) +
xlab("Number of commits") + 
ylab (expression(paste("Number of regular SATDs"))) +
scale_fill_discrete(name = "Subject systems")+
theme(legend.position = "bottom")
ggsave("RQ1_nonDAC_G1.pdf",width=6, height = 4, units = "in")
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 1 rows containing non-finite values (stat_ydensity).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 1 rows containing non-finite values (stat_ydensity).”
# plot without title

# %%
ggplot(g1, aes(fill=group,x=as.factor(commit), y=dac_count))+
scale_y_continuous(trans='log2')+
geom_split_violin(position = "dodge",draw_quantiles=c( 0.25, 0.5, 0.75)) +
xlab("Number of commits") + 
ylab (expression(paste("Number of data-access SATDs"))) +
scale_fill_discrete(name = "Subject systems")+
theme(legend.position = "bottom")

ggsave("RQ1_DAC_G1.pdf",width=6, height = 4, units = "in")
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 32 rows containing non-finite values (stat_ydensity).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 32 rows containing non-finite values (stat_ydensity).”
# plot without title

# %% [markdown]
# <h2>Plots on G2 </h2>

# %%
#1 reaad data
#read g2
sql_g2=read.csv("sql_G2s.csv")
nosql_g2= read.csv("Nosql_G2s.csv")
sql_g2$group="SQL"
nosql_g2$group <-"NoSQL"
g2 <- rbind(sql_g2,nosql_g2)
summary(g2)
# Out:
#     version                                 project      dac_count
#  Min.   : 1.00   AntennaPod_AntennaPod          :  7   Min.   :  0.00
#  1st Qu.: 3.00   jbosstools_jbosstools-hibernate:  7   1st Qu.:  0.00
#  Median : 5.00   microsoft_appcenter-sdk-android:  7   Median :  1.00
#  Mean   : 5.09   mycelium-com_wallet-android    :  7   Mean   : 19.79
#  3rd Qu.: 7.00   nutzam_nutz                    :  7   3rd Qu.:  6.00
#  Max.   :13.00   denimgroup_threadfix           :  6   Max.   :588.00
#                  (Other)                        :160
#  non_dac_count    analysis_group     commit        group
#  Min.   :   0.0   G2:201         Min.   :   1   Length:201
#  1st Qu.:  20.0                  1st Qu.:1001   Class :character
#  Median :  44.0                  Median :2001   Mode  :character
#  Mean   : 114.4                  Mean   :2046
#  3rd Qu.: 160.0                  3rd Qu.:3001
#  Max.   :1015.0                  Max.   :6001

# %%
#g2
ggplot(g2, aes(fill=group,x=as.factor(commit), y=non_dac_count))+
geom_violin(position = "dodge",draw_quantiles=c(0.25, 0.5, 0.75)) +
geom_point(aes(x=3.6, y=17), colour="#EC746C", show.legend=FALSE)+
geom_point(aes(x=3.6, y=51), colour="#EC746C", show.legend=FALSE)+
scale_y_continuous(trans='log2')+
xlab("Number of commits") + 
ylab (expression(paste("Number of regular SATDs"))) +
scale_fill_discrete(name = "Subject systems")+
theme(legend.position = "bottom")

ggsave("RQ1_nonDAC_G2.pdf",width=6, height = 4, units = "in")
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 1 rows containing non-finite values (stat_ydensity).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 1 rows containing non-finite values (stat_ydensity).”
# plot without title

# %%
ggplot(g2, aes(fill=group,x=as.factor(commit), y=dac_count))+
geom_violin(position = "dodge",draw_quantiles=c(0.25,0.5,0.75)) +
scale_y_continuous(trans='log2')+
xlab("Number of commits") + 
ylab (expression(paste("Number of data-access SATDs"))) +
scale_fill_discrete(name = "Subject systems")+
theme(legend.position = "bottom")
ggsave("RQ1_DAC_G2.pdf",width=6, height = 4, units = "in")
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 78 rows containing non-finite values (stat_ydensity).”Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 78 rows containing non-finite values (stat_ydensity).”
# plot without title

# %% [markdown]
# <h2>Plots on G3 </h2>

# %%
#1 reaad data
#read g3
g3=read.csv("sql_G3s.csv")
g3$group="SQL"
summary(g3)
# Out:
#     version                                        project     dac_count
#  Min.   :  1.0   omnirom_android_packages_apps_Settings: 6   Min.   :  0.00
#  1st Qu.:  1.0   wordpress-mobile_WordPress-Android    : 5   1st Qu.:  0.00
#  Median : 21.0   wso2_carbon-apimgt                    : 3   Median :  0.00
#  Mean   : 17.6   adempiere_adempiere                   : 2   Mean   : 27.91
#  3rd Qu.: 21.0   ControlSystemStudio_cs-studio         : 2   3rd Qu.:  8.00
#  Max.   :101.0   dotCMS_core                           : 2   Max.   :519.00
#                  (Other)                               :33
#  non_dac_count    analysis_group     commit         group
#  Min.   :   4.0   G3:53          Min.   :    1   Length:53
#  1st Qu.:  68.0                  1st Qu.:    1   Class :character
#  Median : 180.0                  Median :10001   Mode  :character
#  Mean   : 331.7                  Mean   : 8303
#  3rd Qu.: 378.0                  3rd Qu.:10001
#  Max.   :2263.0                  Max.   :50001

# %%
#g3
ggplot(g3, aes(fill=group,x=as.factor(commit), y=non_dac_count))+
geom_violin(position = "dodge",draw_quantiles=c(0.25, 0.5, 0.75), fill="#59C0C4") +
geom_point()+
scale_y_continuous(trans='log2')+
xlab("Number of commits") + 
ylab (expression(paste("Number of regular SATDs"))) +
scale_fill_discrete(name = "Subject systems")+
guides(color = guide_legend(override.aes = list(fill = "#59C0C4"))) +
theme(legend.position = "none")
ggsave("RQ1_nonDAC_G3.pdf",width=6, height = 4, units = "in")
# Out:
# plot without title

# %%
#g3
ggplot(g3, aes(fill=group,x=as.factor(commit), y=dac_count))+
geom_violin(position = "dodge",draw_quantiles=c(0.25, 0.5, 0.75), fill="#59C0C4") +
geom_point()+
scale_y_continuous(trans='log2')+
ylim(0,1024)+
xlab("Number of commits") + 
ylab (expression(paste("Number of data-access SATDs"))) +
theme(legend.position="none")
ggsave("RQ1_DAC_G3.pdf",width=6, height = 4, units = "in")
# Out:
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
# Warning message in regularize.values(x, y, ties, missing(ties)):
# “collapsing to unique 'x' values”Warning message in regularize.values(x, y, ties, missing(ties)):
# “collapsing to unique 'x' values”
# plot without title
